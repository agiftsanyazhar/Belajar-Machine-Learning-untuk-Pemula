# %%
# !pip install yellowbrick
# Out:
# Collecting yellowbrick
#   Downloading yellowbrick-1.5-py3-none-any.whl (282 kB)
#      ---------------------------------------- 0.0/282.6 kB ? eta -:--:--
#      ------------ -------------------------- 92.2/282.6 kB 2.6 MB/s eta 0:00:01
#      -------------------------------------  276.5/282.6 kB 3.4 MB/s eta 0:00:01
#      -------------------------------------- 282.6/282.6 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.0.0 in f:\tutorial\dicoding indonesia\idcamp 2023\belajar machine learning untuk pemula\.venv\lib\site-packages (from yellowbrick) (1.15.3)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in f:\tutorial\dicoding indonesia\idcamp 2023\belajar machine learning untuk pemula\.venv\lib\site-packages (from yellowbrick) (3.10.8)
# Requirement already satisfied: scikit-learn>=1.0.0 in f:\tutorial\dicoding indonesia\idcamp 2023\belajar machine learning untuk pemula\.venv\lib\site-packages (from yellowbrick) (1.7.2)
# Requirement already satisfied: cycler>=0.10.0 in f:\tutorial\dicoding indonesia\idcamp 2023\belajar machine learning untuk pemula\.venv\lib\site-packages (from yellowbrick) (0.12.1)
# Requirement already satisfied: numpy>=1.16.0 in f:\tutorial\dicoding indonesia\idcamp 2023\belajar machine learning untuk pemula\.venv\lib\site-packages (from yellowbrick) (2.2.6)
# Requirement already satisfied: fonttools>=4.22.0 in f:\tutorial\dicoding indonesia\idcamp 2023\belajar machine learning untuk pemula\.venv\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.62.1)
# Requirement already satisfied: pyparsing>=3 in f:\tutorial\dicoding indonesia\idcamp 2023\belajar machine learning untuk pemula\.venv\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.3.2)
# Requirement already satisfied: packaging>=20.0 in f:\tutorial\dicoding indonesia\idcamp 2023\belajar machine learning untuk pemula\.venv\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (26.0)
# Requirement already satisfied: python-dateutil>=2.7 in f:\tutorial\dicoding indonesia\idcamp 2023\belajar machine learning untuk pemula\.venv\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.9.0.post0)
# Requirement already satisfied: kiwisolver>=1.3.1 in f:\tutorial\dicoding indonesia\idcamp 2023\belajar machine learning untuk pemula\.venv\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in f:\tutorial\dicoding indonesia\idcamp 2023\belajar machine learning untuk pemula\.venv\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.3.2)
# Requirement already satisfied: pillow>=8 in f:\tutorial\dicoding indonesia\idcamp 2023\belajar machine learning untuk pemula\.venv\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (12.1.1)
# Requirement already satisfied: joblib>=1.2.0 in f:\tutorial\dicoding indonesia\idcamp 2023\belajar machine learning untuk pemula\.venv\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in f:\tutorial\dicoding indonesia\idcamp 2023\belajar machine learning untuk pemula\.venv\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (3.6.0)
# Requirement already satisfied: six>=1.5 in f:\tutorial\dicoding indonesia\idcamp 2023\belajar machine learning untuk pemula\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.17.0)
# Installing collected packages: yellowbrick
# Successfully installed yellowbrick-1.5
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import (
    KElbowVisualizer,
)  # Mengimpor KElbowVisualizer untuk visualisasi metode Elbow
from sklearn.datasets import make_blobs

# Membuat dataset buatan
X, y = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=0)

kmeans = KMeans()
visualizer = KElbowVisualizer(kmeans, k=(1, 10))
visualizer.fit(X)
visualizer.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>
